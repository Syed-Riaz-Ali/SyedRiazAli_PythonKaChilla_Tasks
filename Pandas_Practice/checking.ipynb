# %%
# Importing libraries

import pandas as pd
import numpy as np

# Loading the data base of population

p_data = pd.read_csv("FAOSTAT_data_1-12-2022.csv")
p_data
# Out:
#       Domain Code             Domain  Area Code (FAO)         Area  \
# 0              OA  Annual population                2  Afghanistan
# 1              OA  Annual population                2  Afghanistan
# 2              OA  Annual population                2  Afghanistan
# 3              OA  Annual population                2  Afghanistan
# 4              OA  Annual population                2  Afghanistan
# ...           ...                ...              ...          ...
# 70580          OA  Annual population              181     Zimbabwe
# 70581          OA  Annual population              181     Zimbabwe
# 70582          OA  Annual population              181     Zimbabwe
# 70583          OA  Annual population              181     Zimbabwe
# 70584          OA  Annual population              181     Zimbabwe
#
#        Element Code                        Element  Item Code  \
# 0               511  Total Population - Both sexes       3010
# ...

# %%
pak = pd.DataFrame(p_data, columns=["Area Code (FAO)","Area","Year","value"])
pak
# Out:
#        Area Code (FAO)         Area  Year     value
# 0                    2  Afghanistan  1950   7752118
# 1                    2  Afghanistan  1950   4099243
# 2                    2  Afghanistan  1950   3652874
# 3                    2  Afghanistan  1950   7286991
# 4                    2  Afghanistan  1950    465127
# ...                ...          ...   ...       ...
# 70580              181     Zimbabwe  2018  14438802
# 70581              181     Zimbabwe  2018   6879119
# 70582              181     Zimbabwe  2018   7559693
# 70583              181     Zimbabwe  2018  11465748
# 70584              181     Zimbabwe  2018   5447513
#
# [70585 rows x 4 columns]

# %%
df = pak.set_index("Area Code (FAO)")
df
# Out:
#                         Area  Year     value
# Area Code (FAO)
# 2                Afghanistan  1950   7752118
# 2                Afghanistan  1950   4099243
# 2                Afghanistan  1950   3652874
# 2                Afghanistan  1950   7286991
# 2                Afghanistan  1950    465127
# ...                      ...   ...       ...
# 181                 Zimbabwe  2018  14438802
# 181                 Zimbabwe  2018   6879119
# 181                 Zimbabwe  2018   7559693
# 181                 Zimbabwe  2018  11465748
# 181                 Zimbabwe  2018   5447513
#
# [70585 rows x 3 columns]

# %%
keys = {"Afghanistan": 2, "USSR" : 228, "Austrailia" : 10, "Bangladesh" : 16, "Brazil" : 21, "Canada" : 33, "China" : 351, "Finland" : 67, "France" : 68,
        "Germany" : 79, "Greece" : 84, "India" : 100, "Indonesia" : 101, "Iran (Islamic Republic of)" : 102, "Israel" : 105, "Italy" : 106, "Japan" : 110,
        "Mexico" : 138, "New Zealand" : 156, "Pakistan" : 165, "Portugal" : 174, "Russian Federation": 185, "Saudi Arabia" : 194, "Singapore" : 200, 
        "South Africa" : 202, "Srilanka" : 38, "Turkey" : 223, "United Arab Emirates" : 225, "United Kingdom of Great Britain and Northern Ireland": 229,
        "United States of America": 231}
keys
# Out:
# {'Afghanistan': 2,
#  'USSR': 228,
#  'Austrailia': 10,
#  'Bangladesh': 16,
#  'Brazil': 21,
#  'Canada': 33,
#  'China': 351,
#  'Finland': 67,
#  'France': 68,
#  'Germany': 79,
#  'Greece': 84,
#  'India': 100,
#  'Indonesia': 101,
#  'Iran (Islamic Republic of)': 102,
#  'Israel': 105,
#  'Italy': 106,
#  'Japan': 110,
#  'Mexico': 138,
#  'New Zealand': 156,
#  'Pakistan': 165,
#  'Portugal': 174,
#  'Russian Federation': 185,
#  'Saudi Arabia': 194,
#  'Singapore': 200,
#  'South Africa': 202,
#  'Srilanka': 38,
#  'Turkey': 223,
#  'United Arab Emirates': 225,
#  'United Kingdom of Great Britain and Northern Ireland': 229,
#  'United States of America': 231}

# %%
yiu = pd.Series(keys)
yiu
# Out:
# Afghanistan                                               2
# USSR                                                    228
# Austrailia                                               10
# Bangladesh                                               16
# Brazil                                                   21
# Canada                                                   33
# China                                                   351
# Finland                                                  67
# France                                                   68
# Germany                                                  79
# Greece                                                   84
# India                                                   100
# Indonesia                                               101
# Iran (Islamic Republic of)                              102
# Israel                                                  105
# Italy                                                   106
# ...

# %%
w = yiu["Turkey"]
w
# Out:
# 223

# %%
df_Afgh = df.loc[w]
df_Afgh
# Out:
#                    Area  Year     value
# Area Code (FAO)
# 223              Turkey  1950  21408399
# 223              Turkey  1950  10764544
# 223              Turkey  1950  10643854
# 223              Turkey  1950  16104671
# 223              Turkey  1950   5303730
# ...                 ...   ...       ...
# 223              Turkey  2018  82340088
# 223              Turkey  2018  40611933
# 223              Turkey  2018  41728157
# 223              Turkey  2018  20362183
# 223              Turkey  2018  61554688
#
# [345 rows x 3 columns]

# %%
df_year = df_Afgh.set_index("Year")
df_year
# Out:
#         Area     value
# Year
# 1950  Turkey  21408399
# 1950  Turkey  10764544
# 1950  Turkey  10643854
# 1950  Turkey  16104671
# 1950  Turkey   5303730
# ...      ...       ...
# 2018  Turkey  82340088
# 2018  Turkey  40611933
# 2018  Turkey  41728157
# 2018  Turkey  20362183
# 2018  Turkey  61554688
#
# [345 rows x 2 columns]

# %%
year_1950 = df_year.loc[1950]
year_1950
# Out:
#         Area     value
# Year
# 1950  Turkey  21408399
# 1950  Turkey  10764544
# 1950  Turkey  10643854
# 1950  Turkey  16104671
# 1950  Turkey   5303730

# %%
y = np.arange(1950, 2019, step =1)
y
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
ay = np.delete(y, 68)
ay
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017])

# %%
year_pop_Afgh = []
for i in range(68):
    y1 = df_year.loc[y[i]]
    pop = y1["value"].sum()
    year_pop_Afgh.append(pop.round())

year_pop_Afgh
# Out:
# [64225198,
#  65853624,
#  67526852,
#  69244749,
#  71006738,
#  72811784,
#  74658366,
#  76544459,
#  78467765,
#  80425887,
#  82417015,
#  84440712,
#  86498463,
#  88594069,
#  90732751,
#  92918955,
#  95152488,
#  97433947,
#  99769361,
#  102166142,
#  104628866,
#  107161770,
#  109761753,
#  112416963,
#  115110802,
#  117831718,
#  120568639,
#  123324835,
#  126119910,
#  128982075,
#  131927864,
#  134965181,
#  138076179,
#  141220364,
#  144342418,
#  147401748,
#  150385578,
#  153302732,
#  156161233,
#  158977395,
#  161765217,
#  164521716,
#  167246769,
#  169961341,
#  172692545,
#  175459290,
#  178269768,
#  181117638,
#  183988931,
#  186862114,
#  189720511,
#  192575960,
#  195433778,
#  198264607,
#  201029715,
#  203710336,
#  206277024,
#  208760983,
#  211277248,
#  213981990,
#  216980894,
#  220295959,
#  223871963,
#  227638249,
#  231489146,
#  235330294,
#  239168165,
#  242977921]

# %%
b = np.array(year_pop_Afgh)
b
# Out:
# array([ 64225198,  65853624,  67526852,  69244749,  71006738,  72811784,
#         74658366,  76544459,  78467765,  80425887,  82417015,  84440712,
#         86498463,  88594069,  90732751,  92918955,  95152488,  97433947,
#         99769361, 102166142, 104628866, 107161770, 109761753, 112416963,
#        115110802, 117831718, 120568639, 123324835, 126119910, 128982075,
#        131927864, 134965181, 138076179, 141220364, 144342418, 147401748,
#        150385578, 153302732, 156161233, 158977395, 161765217, 164521716,
#        167246769, 169961341, 172692545, 175459290, 178269768, 181117638,
#        183988931, 186862114, 189720511, 192575960, 195433778, 198264607,
#        201029715, 203710336, 206277024, 208760983, 211277248, 213981990,
#        216980894, 220295959, 223871963, 227638249, 231489146, 235330294,
#        239168165, 242977921], dtype=int64)

# %%
o = pd.DataFrame({"Year" : ay, "Population": b})
o
# Out:
#     Year  Population
# 0   1950    64225198
# 1   1951    65853624
# 2   1952    67526852
# 3   1953    69244749
# 4   1954    71006738
# ..   ...         ...
# 63  2013   227638249
# 64  2014   231489146
# 65  2015   235330294
# 66  2016   239168165
# 67  2017   242977921
#
# [68 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid")

pop_plot_of_afgh = sns.lineplot(data=o, x = "Year", y="Population")
plt.title("Population of Afghanistan")
pop_plot_of_afgh
# Out:
# <AxesSubplot:title={'center':'Population of Afghanistan'}, xlabel='Year', ylabel='Population'>
