# %%
# Importing libraries

import pandas as pd
import numpy as np

# Loading the data base of population

p_data = pd.read_csv("FAOSTAT_data_1-12-2022.csv")
p_data
# Out:
#       Domain Code             Domain  Area Code (FAO)         Area  \
# 0              OA  Annual population                2  Afghanistan
# 1              OA  Annual population                2  Afghanistan
# 2              OA  Annual population                2  Afghanistan
# 3              OA  Annual population                2  Afghanistan
# 4              OA  Annual population                2  Afghanistan
# ...           ...                ...              ...          ...
# 70580          OA  Annual population              181     Zimbabwe
# 70581          OA  Annual population              181     Zimbabwe
# 70582          OA  Annual population              181     Zimbabwe
# 70583          OA  Annual population              181     Zimbabwe
# 70584          OA  Annual population              181     Zimbabwe
#
#        Element Code                        Element  Item Code  \
# 0               511  Total Population - Both sexes       3010
# ...

# %%
pak = pd.DataFrame(p_data, columns=["Area Code (FAO)","Area","Year","Value","Element","Element Code"])
pak
# Out:
#        Area Code (FAO)         Area  Year      Value  \
# 0                    2  Afghanistan  1950   7752.118
# 1                    2  Afghanistan  1950   4099.243
# 2                    2  Afghanistan  1950   3652.874
# 3                    2  Afghanistan  1950   7286.991
# 4                    2  Afghanistan  1950    465.127
# ...                ...          ...   ...        ...
# 70580              181     Zimbabwe  2018  14438.802
# 70581              181     Zimbabwe  2018   6879.119
# 70582              181     Zimbabwe  2018   7559.693
# 70583              181     Zimbabwe  2018  11465.748
# 70584              181     Zimbabwe  2018   5447.513
#
#                              Element  Element Code
# 0      Total Population - Both sexes           511
# 1            Total Population - Male           512
# 2          Total Population - Female           513
# 3                   Rural population           551
# 4                   Urban population           561
# ...

# %%
df = pak.set_index("Area Code (FAO)")
df
# Out:
#                         Area  Year      Value                        Element  \
# Area Code (FAO)
# 2                Afghanistan  1950   7752.118  Total Population - Both sexes
# 2                Afghanistan  1950   4099.243        Total Population - Male
# 2                Afghanistan  1950   3652.874      Total Population - Female
# 2                Afghanistan  1950   7286.991               Rural population
# 2                Afghanistan  1950    465.127               Urban population
# ...                      ...   ...        ...                            ...
# 181                 Zimbabwe  2018  14438.802  Total Population - Both sexes
# 181                 Zimbabwe  2018   6879.119        Total Population - Male
# 181                 Zimbabwe  2018   7559.693      Total Population - Female
# 181                 Zimbabwe  2018  11465.748               Rural population
# 181                 Zimbabwe  2018   5447.513               Urban population
#
# ...

# %%
df_Afgh = df.loc[2]
df_Afgh
# Out:
#                         Area  Year      Value                        Element  \
# Area Code (FAO)
# 2                Afghanistan  1950   7752.118  Total Population - Both sexes
# 2                Afghanistan  1950   4099.243        Total Population - Male
# 2                Afghanistan  1950   3652.874      Total Population - Female
# 2                Afghanistan  1950   7286.991               Rural population
# 2                Afghanistan  1950    465.127               Urban population
# ...                      ...   ...        ...                            ...
# 2                Afghanistan  2018  37171.921  Total Population - Both sexes
# 2                Afghanistan  2018  19093.043        Total Population - Male
# 2                Afghanistan  2018  18078.879      Total Population - Female
# 2                Afghanistan  2018  27099.874               Rural population
# 2                Afghanistan  2018   9273.302               Urban population
#
# ...

# %%
#pop_Afgh = df_Afgh["Value"].sum()
#pop_Afgh

# %%
# year = df_Afgh[df_Afgh.duplicated("Year")]
#year

# %%
df_year = df_Afgh.set_index("Year")
df_year
# Out:
#              Area      Value                        Element  Element Code
# Year
# 1950  Afghanistan   7752.118  Total Population - Both sexes           511
# 1950  Afghanistan   4099.243        Total Population - Male           512
# 1950  Afghanistan   3652.874      Total Population - Female           513
# 1950  Afghanistan   7286.991               Rural population           551
# 1950  Afghanistan    465.127               Urban population           561
# ...           ...        ...                            ...           ...
# 2018  Afghanistan  37171.921  Total Population - Both sexes           511
# 2018  Afghanistan  19093.043        Total Population - Male           512
# 2018  Afghanistan  18078.879      Total Population - Female           513
# 2018  Afghanistan  27099.874               Rural population           551
# 2018  Afghanistan   9273.302               Urban population           561
#
# [345 rows x 4 columns]

# %%
year_1950 = df_year.loc[1950]
year_1950
# Out:
#              Area     Value                        Element  Element Code
# Year
# 1950  Afghanistan  7752.118  Total Population - Both sexes           511
# 1950  Afghanistan  4099.243        Total Population - Male           512
# 1950  Afghanistan  3652.874      Total Population - Female           513
# 1950  Afghanistan  7286.991               Rural population           551
# 1950  Afghanistan   465.127               Urban population           561

# %%
total_pop_1950 = year_1950["Value"].sum()
total_pop_1950.round()
# Out:
# 23256.0

# %%
y = np.arange(1950, 2019, step =1)
y
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
year_pop_Afgh = []
for i in range(68):
    y1 = df_year.loc[y[i]]
    pop = y1["Value"].sum()
    year_pop_Afgh.append(pop.round())

year_pop_Afgh

#year_Afgh = pd.DataFrame({"year" : y[i], "population": pop[i]})
#year_Afgh
    # print("In the year " , y[i], " the population is ", pop.round())
# Out:
# [23256.0,
#  23520.0,
#  23807.0,
#  24118.0,
#  24453.0,
#  24813.0,
#  25197.0,
#  25606.0,
#  26041.0,
#  26502.0,
#  26990.0,
#  27506.0,
#  28049.0,
#  28620.0,
#  29221.0,
#  29851.0,
#  30502.0,
#  31172.0,
#  31878.0,
#  32642.0,
#  33473.0,
#  34369.0,
#  35304.0,
#  36246.0,
#  37147.0,
#  37969.0,
#  38726.0,
#  39410.0,
#  39920.0,
#  40129.0,
#  39961.0,
#  39397.0,
#  38515.0,
#  37465.0,
#  36456.0,
#  35659.0,
#  35073.0,
#  34712.0,
#  34777.0,
#  35515.0,
#  37074.0,
#  39592.0,
#  42952.0,
#  46728.0,
#  50324.0,
#  53321.0,
#  55530.0,
#  57096.0,
#  58340.0,
#  59745.0,
#  61654.0,
#  64180.0,
#  67181.0,
#  70427.0,
#  73572.0,
#  76379.0,
#  78760.0,
#  80818.0,
#  82739.0,
#  84794.0,
#  87174.0,
#  89943.0,
#  93020.0,
#  96271.0,
#  99500.0,
#  102564.0,
#  105422.0,
#  108122.0]

# %%
b = np.array(year_pop_Afgh)
b
# Out:
# array([ 23256.,  23520.,  23807.,  24118.,  24453.,  24813.,  25197.,
#         25606.,  26041.,  26502.,  26990.,  27506.,  28049.,  28620.,
#         29221.,  29851.,  30502.,  31172.,  31878.,  32642.,  33473.,
#         34369.,  35304.,  36246.,  37147.,  37969.,  38726.,  39410.,
#         39920.,  40129.,  39961.,  39397.,  38515.,  37465.,  36456.,
#         35659.,  35073.,  34712.,  34777.,  35515.,  37074.,  39592.,
#         42952.,  46728.,  50324.,  53321.,  55530.,  57096.,  58340.,
#         59745.,  61654.,  64180.,  67181.,  70427.,  73572.,  76379.,
#         78760.,  80818.,  82739.,  84794.,  87174.,  89943.,  93020.,
#         96271.,  99500., 102564., 105422., 108122.])

# %%
c = np.array([y,b])
c
# Out:
# C:\Users\syedriaz\AppData\Local\Temp/ipykernel_10616/2673555390.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   c = np.array([y,b])
# array([array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#               1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#               1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#               1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#               1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#               2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#               2016, 2017, 2018])                                               ,
# ...

# %%
ay = np.delete(y, 68)
ay
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017])

# %%
ay.shape
# Out:
# (68,)

# %%
o = pd.DataFrame({"Year" : ay, "Population": b})
o
# Out:
#     Year  Population
# 0   1950     23256.0
# 1   1951     23520.0
# 2   1952     23807.0
# 3   1953     24118.0
# 4   1954     24453.0
# ..   ...         ...
# 63  2013     96271.0
# 64  2014     99500.0
# 65  2015    102564.0
# 66  2016    105422.0
# 67  2017    108122.0
#
# [68 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("darkgrid")

pop_plot_of_afgh = sns.lineplot(data=o, x = "Year", y="Population")
plt.title("Population of Afghanistan")
pop_plot_of_afgh
# Out:
# <AxesSubplot:title={'center':'Population of Afghanistan'}, xlabel='Year', ylabel='Population'>
